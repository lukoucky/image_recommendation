# %%
path_prefix = '/home/backend/'
# %matplotlib inline
import sys
sys.path.insert(1, path_prefix)
from instance_segmentation_model import InstanceSegmentationModel
from dataset import Dataset

# %%
model = InstanceSegmentationModel('mask_rcnn_coco.h5')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py:574: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
d = Dataset('coco_segment', '/home/backend/val2017', model);

# %%
for i in range(5):
    img = d.get_random_image()
    f = d.get_features_for_image(img)
    d.model.print_categories(f)
    d.plot_images(d.get_similar_images(img), img)
    print('\n------------------------------------------------------------------------------------------------------\n')
# Out:
# Score  - Category
# 0.9660 - toilet
# 0.9932 - sink
# ------------------------------------------------------------------------------------------------------
#
# Score  - Category
# 0.9997 - person
# 0.8634 - dining table
# ------------------------------------------------------------------------------------------------------
#
# Score  - Category
# 0.9977 - person
# 0.9089 - car
# 0.9982 - horse
# ------------------------------------------------------------------------------------------------------
#
# Score  - Category
# 0.9597 - knife
# 0.9852 - sandwich
# 0.9329 - dining table
# ------------------------------------------------------------------------------------------------------
#
# Score  - Category
# 0.9999 - person
# 0.8290 - car
# 0.7715 - bench
# 0.9986 - bird
# 0.8693 - handbag
# ------------------------------------------------------------------------------------------------------
